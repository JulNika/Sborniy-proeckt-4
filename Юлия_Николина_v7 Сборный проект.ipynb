# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Комментарий ревьюера</b>
#
#
# Привет, Юлия! Давай знакомиться! Меня зовут Дмитрий Махортов, и я буду проверять твой проект. Сразу предлагаю общение на «ты» 🙂, но если тебе это не комфортно, то дай знать, и мы перейдем на «вы».
#
#
# Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе погрузиться в увлекательный мир работы с данными и вырасти в крепкого профи. Это отдаленная цель. А ближайшая - сделать твою работу еще лучше )).
#
#
# Все ключевые этапы в работе выполнены, и я вижу что с проектом ты справшяешься. Есть моменты, которые нужно доработать, но я уверен, у тебя все получится.
#
# Расскажу как обычно проходит проверка:
# Бывают моменты, которые требуют пристального внимания. Комментарии по ним выделены <span style='background-color:#F7B3A4'> красным цветом </span> и обозначены значком 🛑. После их доработки проект будет принят.  🙂
#
# <span style='background-color:#B7EBA7'> Зеленым цветом </span> и значком ✅ отмечены удачные и элегантные решения, на которые можно опираться в будущих проектах. Или советы «со звездочкой», которые помогут тебе в будущем.
#
# <span style='background-color:#F9EDA6'>Жёлтым цветом </span> и значком ⚠️ выделено то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас (однако это не обязательно).
#
# Давай работать над проектом в диалоге: **если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом**. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения. Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта оперативнее.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментария студента</b></font>
#
# Привет, Дмитрий! Приятно познакомиться, давай на ты)
#
# </div>

# %% [markdown]
# # СБОРНЫЙ ПРОЕКТ - 4

# %% [markdown]
# ***0.1  Описание данных***
# Данные лежат в папке /datasets/image_search/ или доступны по ссылке.
#
# В файле train_dataset.csv находится информация, необходимая для обучения: имя файла изображения, идентификатор описания и текст описания. Для одной картинки может быть доступно до 5 описаний. Идентификатор описания имеет формат <имя файла изображения>#<порядковый номер описания>.
#
# В папке train_images содержатся изображения для тренировки модели.
#
# В файле CrowdAnnotations.tsv — данные по соответствию изображения и описания, полученные с помощью краудсорсинга. Номера колонок и соответствующий тип данных:
#
# Имя файла изображения.
# Идентификатор описания.
# Доля людей, подтвердивших, что описание соответствует изображению.
# Количество человек, подтвердивших, что описание соответствует изображению.
# Количество человек, подтвердивших, что описание не соответствует изображению.
#
#
# В файле ExpertAnnotations.tsv содержатся данные по соответствию изображения и описания, полученные в результате опроса экспертов. Номера колонок и соответствующий тип данных:
#
# Имя файла изображения.
# Идентификатор описания.
# 3, 4, 5 — оценки трёх экспертов.
#
# Эксперты ставят оценки по шкале от 1 до 4, где 1 — изображение и запрос совершенно не соответствуют друг другу, 2 — запрос содержит элементы описания изображения, но в целом запрос тексту не соответствует, 3 — запрос и текст соответствуют с точностью до некоторых деталей, 4 — запрос и текст соответствуют полностью.
#
# В файле test_queries.csv находится информация, необходимая для тестирования: идентификатор запроса, текст запроса и релевантное изображение. Для одной картинки может быть доступно до 5 описаний. Идентификатор описания имеет формат <имя файла изображения>#<порядковый номер описания>.
#
# В папке test_images содержатся изображения для тестирования модели.

# %%
# !pip install -q --upgrade keras-nlp tensorflow
# !pip install -q numpy --upgrade
# !pip install -q transformers
# !pip install -q --upgrade pip
# !pip install -q ipywidgets

# %% [markdown]
# nltk.download('stopwords') # поддерживает удаление стоп-слов
# nltk.download('punkt') # делит текст на список предложений
# nltk.download('wordnet') # проводит лемматизацию
# nltk.download('omw-1.4')

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
#
#
# Я редко оставляю красные комментарии за установку библиотек. Но здесь у тебя просто ужас-ужас.
#
# Я вижу что  установку numpy три раза, установку tensorflow - дважды. Заодно ты устанавилваешь конкурирующий фреймворк torch и torchvision. Зачем они тебе, если в проекте ты используешь Keras? Затем ты загружаешь конкурирующие решения keras_nlp и transformers....
#
# Пожалуйста убери все лишнее. И отсюда и из импортов.
#
# Я вижу что ты работаешь локально, поэтому стандартные библиотеки НЕ НУЖНО устанавливать. Они уже давно установлены и у тебя и у меня и где бы мы ни запускали этот код. Можешь оставить установку редких библиотек - transformers/keras-nlp. Но только то, что реально нужно.
#
# ---
#
# Я вижу что ты прячешь установку библитек и в импорты. Так точно делать не нужно. Предоставь возможность каждому, кто будет запускать твой ноутбук решать, хочет ли он устанавливать ту или иную библиотеку в свое окружение.
#
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Лично меня очень утомляют простыни логов после установки библиотек. Я их все равно никто не читает. Можно добавить флаг -q и соединить все установки в одну строку. Будет гораздо аккуратноее.
#
#     !pip install -q transformers catboost optuna keras-tuner
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментария студента</b></font>
#
# Удлила лишнее. Убрала установку библиотек из импортов.
#
# Пока делала проект, выскакивали разные ошибки, что не установлены приложения, делала это по ходу, несколько раз меняла, а в итоге лишнее не удалила.
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#     <b>v2</b> ОК, вижу что сейчас удалены дубли, давай на этом ограничимся </div>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import pickle
import urllib.request
import zipfile
import os.path
import nltk
import tensorflow as tf
import keras_nlp
import os
import re
import warnings
warnings.filterwarnings('ignore')


from nltk.corpus import stopwords
nltk.download('stopwords')
from tqdm import tqdm_notebook as tqdm
from tqdm.notebook import tqdm
from tqdm import tqdm

from tqdm import notebook
from PIL import Image
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

from transformers import AutoTokenizer, AutoModel
from sklearn.model_selection import GroupShuffleSplit
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import (Dense, GlobalAveragePooling2D, Flatten, Dropout, BatchNormalization)
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.resnet import ResNet50
from tensorflow import keras
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import (Conv2D,
                                     Flatten,
                                     Dense,
                                     AveragePooling2D,
                                     GlobalAveragePooling2D)
from nltk.corpus import stopwords as nltk_stopwords


from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from nltk.corpus import wordnet
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_score, GridSearchCV, GroupShuffleSplit, GridSearchCV
from sklearn.pipeline import Pipeline
# Out:
# C:\Users\LeeLoo\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Using TensorFlow backend
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\LeeLoo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## 1. Исследовательский анализ данных
#
# Наш датасет содержит экспертные и краудсорсинговые оценки соответствия текста и изображения.
#
# В файле с экспертными мнениями для каждой пары изображение-текст имеются оценки от трёх специалистов. Для решения задачи вы должны эти оценки агрегировать — превратить в одну. Существует несколько способов агрегации оценок, самый простой — голосование большинства: за какую оценку проголосовала большая часть экспертов (в нашем случае 2 или 3), та оценка и ставится как итоговая. Поскольку число экспертов меньше числа классов, может случиться, что каждый эксперт поставит разные оценки, например: 1, 4, 2. В таком случае данную пару изображение-текст можно исключить из датасета.
#
# Вы можете воспользоваться другим методом агрегации оценок или придумать свой.
#
# В файле с краудсорсинговыми оценками информация расположена в таком порядке:
#
# 1. Доля исполнителей, подтвердивших, что текст **соответствует** картинке.
# 2. Количество исполнителей, подтвердивших, что текст **соответствует** картинке.
# 3. Количество исполнителей, подтвердивших, что текст **не соответствует** картинке.
#
# После анализа экспертных и краудсорсинговых оценок выберите либо одну из них, либо объедините их в одну по какому-то критерию: например, оценка эксперта принимается с коэффициентом 0.6, а крауда — с коэффициентом 0.4.
#
# Ваша модель должна возвращать на выходе вероятность соответствия изображения тексту, поэтому целевая переменная должна иметь значения от 0 до 1.

# %% [markdown]
# ***Загрузим и посмотрим имеюшиеся данные***

# %%
PATH = '/Sborniy proeck 4/to_upload'


def read_df(path=PATH) -> pd.DataFrame:

    '''читаем датафреймы из указанной директории'''

    df_train = pd.read_csv(Path(path, 'train_dataset.csv'))#.sample(frac=0.1)
    df_crowd = pd.read_csv(Path(path, 'CrowdAnnotations.tsv'), sep='\t',
                           names=['image', 'query_id', 'share_pos', 'count_pos', 'count_neg'])
    df_expert = pd.read_csv(Path(path, 'ExpertAnnotations.tsv'), sep='\t',
                           names=['image', 'query_id', 'first', 'second', 'third'])

    df_test_queries= pd.read_csv(Path(path, 'test_queries.csv'), index_col=[0], sep='|')
    df_images = pd.read_csv(Path(path, 'test_images.csv'), sep='|')

    return df_train, df_crowd, df_expert, df_test_queries, df_images

df_train, df_crowd, df_expert, df_queries, df_images = read_df()

# %%
df_train
# Out:
#                           image                     query_id  \
# 0     1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2
# 1     1262583859_653f1469a9.jpg  2549968784_39bfbe44f9.jpg#2
# 2     2447284966_d6bbdb4b6e.jpg  2549968784_39bfbe44f9.jpg#2
# 3     2549968784_39bfbe44f9.jpg  2549968784_39bfbe44f9.jpg#2
# 4     2621415349_ef1a7e73be.jpg  2549968784_39bfbe44f9.jpg#2
# ...                         ...                          ...
# 5817   757046028_ff5999f91b.jpg  2061144717_5b3a1864f0.jpg#2
# 5818   799486353_f665d7b0f0.jpg  2196107384_361d73a170.jpg#2
# 5819   909808296_23c427022d.jpg  2112921744_92bf706805.jpg#2
# 5820   929679367_ff8c7df2ee.jpg  3651971126_309e6a5e22.jpg#2
# 5821   968081289_cdba83ce2e.jpg  2292406847_f366350600.jpg#2
#
#                                              query_text
# 0     A young child is wearing blue goggles and sitt...
# 1     A young child is wearing blue goggles and sitt...
# 2     A young child is wearing blue goggles and sitt...
# ...

# %%
df_train.info()
print('Количество уникальных фото на трейне:', len(df_train['image'].unique()))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5822 entries, 0 to 5821
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   image       5822 non-null   object
#  1   query_id    5822 non-null   object
#  2   query_text  5822 non-null   object
# dtypes: object(3)
# memory usage: 136.6+ KB
# Количество уникальных фото на трейне: 1000

# %%
#наличие полных дубликатов
print(df_train.duplicated().sum())
# Out:
# 0

# %%
df_queries.head()
# Out:
#                       query_id  \
# 0  1177994172_10d143cb8d.jpg#0
# 1  1177994172_10d143cb8d.jpg#1
# 2  1177994172_10d143cb8d.jpg#2
# 3  1177994172_10d143cb8d.jpg#3
# 4  1177994172_10d143cb8d.jpg#4
#
#                                           query_text  \
# 0  Two blonde boys , one in a camouflage shirt an...
# 1  Two boys are squirting water guns at each other .
# 2            Two boys spraying each other with water
# 3  Two children wearing jeans squirt water at eac...
# 4  Two young boys are squirting water at each oth...
#
#                        image
# 0  1177994172_10d143cb8d.jpg
# 1  1177994172_10d143cb8d.jpg
# 2  1177994172_10d143cb8d.jpg
# 3  1177994172_10d143cb8d.jpg
# 4  1177994172_10d143cb8d.jpg

# %%
#наличие полных дубликатов
print(df_queries.duplicated().sum())
# Out:
# 0

# %%
df_queries.info()
print('Количество уникальных фото на тесте:', len(df_queries['image'].unique()))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   query_id    500 non-null    object
#  1   query_text  500 non-null    object
#  2   image       500 non-null    object
# dtypes: object(3)
# memory usage: 15.6+ KB
# Количество уникальных фото на тесте: 100

# %%
 df_crowd.head()
# Out:
#                        image                     query_id  share_pos  \
# 0  1056338697_4f7d7ce270.jpg  1056338697_4f7d7ce270.jpg#2        1.0
# 1  1056338697_4f7d7ce270.jpg   114051287_dd85625a04.jpg#2        0.0
# 2  1056338697_4f7d7ce270.jpg  1427391496_ea512cbe7f.jpg#2        0.0
# 3  1056338697_4f7d7ce270.jpg  2073964624_52da3a0fc4.jpg#2        0.0
# 4  1056338697_4f7d7ce270.jpg  2083434441_a93bc6306b.jpg#2        0.0
#
#    count_pos  count_neg
# 0          3          0
# 1          0          3
# 2          0          3
# 3          0          3
# 4          0          3

# %%
#наличие полных дубликатов
print( df_crowd.duplicated().sum())
# Out:
# 0

# %%
 df_crowd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47830 entries, 0 to 47829
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   image      47830 non-null  object
#  1   query_id   47830 non-null  object
#  2   share_pos  47830 non-null  float64
#  3   count_pos  47830 non-null  int64
#  4   count_neg  47830 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.8+ MB

# %%
df_expert.head()
# Out:
#                        image                     query_id  first  second  \
# 0  1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2      1       1
# 1  1056338697_4f7d7ce270.jpg  2718495608_d8533e3ac5.jpg#2      1       1
# 2  1056338697_4f7d7ce270.jpg  3181701312_70a379ab6e.jpg#2      1       1
# 3  1056338697_4f7d7ce270.jpg  3207358897_bfa61fa3c6.jpg#2      1       2
# 4  1056338697_4f7d7ce270.jpg  3286822339_5535af6b93.jpg#2      1       1
#
#    third
# 0      1
# 1      2
# 2      2
# 3      2
# 4      2

# %%
#наличие полных дубликатов
print(df_expert.duplicated().sum())
# Out:
# 0

# %%
df_expert.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5822 entries, 0 to 5821
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   image     5822 non-null   object
#  1   query_id  5822 non-null   object
#  2   first     5822 non-null   int64
#  3   second    5822 non-null   int64
#  4   third     5822 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 227.5+ KB

# %%
df_images.head()
# Out:
#                        image
# 0  3356748019_2251399314.jpg
# 1  2887171449_f54a2b9f39.jpg
# 2  3089107423_81a24eaf18.jpg
# 3  1429546659_44cb09cbe2.jpg
# 4  1177994172_10d143cb8d.jpg

# %%
df_images.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   image   100 non-null    object
# dtypes: object(1)
# memory usage: 928.0+ bytes

# %% [markdown]
# ***Посмотрим на изображдения для обучения и тренировки модели***

# %%
#изображения для обучения

samples_train = list(df_train['image'].sample(8))

fig = plt.figure(figsize=(10,10))
for i in range(8):
    fig.add_subplot(4, 4, i+1)
    image = Image.open(Path(PATH, 'train_images', samples_train[i]))
    plt.imshow(image)
    plt.xticks([])
    plt.yticks([])
    plt.tight_layout()

# %%
#изображения для тестирования

samples_test = list(df_queries['image'].sample(8))

fig = plt.figure(figsize=(10,10))
for i in range(8):
    fig.add_subplot(4, 4, i+9)
    image = Image.open(Path(PATH, 'test_images', samples_test[i]))
    plt.imshow(image)
    plt.xticks([])
    plt.yticks([])
    plt.tight_layout()

# %% [markdown]
# ### Выводы:
#
# Мы загрузили и ознакомились с данными.
#
#
# В обучающем наборе данных 5822 запросов, при этом количесвто уникальных фото = 1000, значит некторые фото по запросам повторяются.
# В тестовой выборке: 500 запросов и 100 уникальнгых фото в ним.
#
# Во всех файлах полных дубликатов нет.
#
#
# Перейдём к агрегации оценок для получения тестов.

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Отлично, проведено подробное знакомство с данными.</div>

# %% [markdown]
# ## Агрегация оценок

# %% [markdown]
# Наш датасет содержит экспертные и краудсорсинговые оценки соответствия текста и изображения.
#
# В файле с экспертными мнениями для каждой пары изображение-текст имеются оценки от трёх специалистов. Для решения задачи вы должны эти оценки агрегировать — превратить в одну. Существует несколько способов агрегации оценок, самый простой — голосование большинства: за какую оценку проголосовала большая часть экспертов (в нашем случае 2 или 3), та оценка и ставится как итоговая. Поскольку число экспертов меньше числа классов, может случиться, что каждый эксперт поставит разные оценки, например: 1, 4, 2. В таком случае данную пару изображение-текст можно исключить из датасета.
#
# Вы можете воспользоваться другим методом агрегации оценок или придумать свой.
#
# В файле с краудсорсинговыми оценками информация расположена в таком порядке:
#
# Доля исполнителей, подтвердивших, что текст соответствует картинке.
# Количество исполнителей, подтвердивших, что текст соответствует картинке.
# Количество исполнителей, подтвердивших, что текст не соответствует картинке.
# После анализа экспертных и краудсорсинговых оценок выберите либо одну из них, либо объедините их в одну по какому-то критерию: например, оценка эксперта принимается с коэффициентом 0.6, а крауда — с коэффициентом 0.4.
#
# Ваша модель должна возвращать на выходе вероятность соответствия изображения тексту, поэтому целевая переменная должна иметь значения от 0 до 1.

# %% [markdown]
# ***Агрегация экспертных оценок***

# %%
def expert_aggregate(row):

    #если все 3 эксперта поставили разные оценки, то им ставим 0 и в дальшнейшем удалим из датасета
    if row['first']== row['second']== row['third']:
        row['agg'] = row['first']

    elif row['second'] == row['third']:
        row['agg'] = row['third']

    elif row['first'] == row['second']:
        row['agg'] = row['second']
    #тут укажем 1, то  есть изображение не соответсвует тексту и картинке, не будем вводить новую пепеменную 0
    else:
        row['agg'] = 1
    return row

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  👍 </div>

# %%
df_expert.head()
# Out:
#                        image                     query_id  first  second  \
# 0  1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2      1       1
# 1  1056338697_4f7d7ce270.jpg  2718495608_d8533e3ac5.jpg#2      1       1
# 2  1056338697_4f7d7ce270.jpg  3181701312_70a379ab6e.jpg#2      1       1
# 3  1056338697_4f7d7ce270.jpg  3207358897_bfa61fa3c6.jpg#2      1       2
# 4  1056338697_4f7d7ce270.jpg  3286822339_5535af6b93.jpg#2      1       1
#
#    third
# 0      1
# 1      2
# 2      2
# 3      2
# 4      2

# %%
#применим агрегирующую функцию к экспертным оценкам

df_expert = df_expert.apply(expert_aggregate, axis=1)
df_expert.head()
# Out:
#                        image                     query_id  first  second  \
# 0  1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2      1       1
# 1  1056338697_4f7d7ce270.jpg  2718495608_d8533e3ac5.jpg#2      1       1
# 2  1056338697_4f7d7ce270.jpg  3181701312_70a379ab6e.jpg#2      1       1
# 3  1056338697_4f7d7ce270.jpg  3207358897_bfa61fa3c6.jpg#2      1       2
# 4  1056338697_4f7d7ce270.jpg  3286822339_5535af6b93.jpg#2      1       1
#
#    third  agg
# 0      1    1
# 1      2    1
# 2      2    1
# 3      2    2
# 4      2    1

# %%
#проверка работы оператора elif и функции агрегации
df_expert.tail(10)
# Out:
#                          image                     query_id  first  second  \
# 5812  979383193_0a542a059d.jpg  3482062809_3b694322c4.jpg#2      1       2
# 5813  979383193_0a542a059d.jpg  3585598356_8ce815bbb9.jpg#2      1       1
# 5814  997722733_0cb5439472.jpg  2641770481_c98465ff35.jpg#2      1       1
# 5815  997722733_0cb5439472.jpg  2932740428_b15384f389.jpg#2      1       1
# 5816  997722733_0cb5439472.jpg  2968182121_b3b491df85.jpg#2      1       1
# 5817  997722733_0cb5439472.jpg  2981702521_2459f2c1c4.jpg#2      1       1
# 5818  997722733_0cb5439472.jpg  2985679744_75a7102aab.jpg#2      1       1
# 5819  997722733_0cb5439472.jpg  3150742439_b8a352e1e0.jpg#2      1       1
# 5820  997722733_0cb5439472.jpg  3375070563_3c290a7991.jpg#2      1       1
# 5821  997722733_0cb5439472.jpg   486917990_72bd4069af.jpg#2      3       3
#
#       third  agg
# 5812      2    2
# 5813      1    1
# 5814      2    1
# 5815      2    1
# 5816      1    1
# 5817      1    1
# ...

# %%
#посмотрим какие есть уникальные значения среди агрегированных оценок

df_expert['agg'].unique()
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
#удалим оценки экспертов, оставив только агрегированную оценку

df_expert = df_expert.drop(columns=['first','second','third'])
df_expert.head()
# Out:
#                        image                     query_id  agg
# 0  1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2    1
# 1  1056338697_4f7d7ce270.jpg  2718495608_d8533e3ac5.jpg#2    1
# 2  1056338697_4f7d7ce270.jpg  3181701312_70a379ab6e.jpg#2    1
# 3  1056338697_4f7d7ce270.jpg  3207358897_bfa61fa3c6.jpg#2    2
# 4  1056338697_4f7d7ce270.jpg  3286822339_5535af6b93.jpg#2    1

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Не стоит выводить весь датафрейм. Да, внешне ты видишь первые и последние пять строк. Но под капотом интерпретатор python работает со всем датафреймом, занимается оперативная память, пишутся служебные файлы... По итогу это может привести к замедлению работы и проблемам с работоспособностью тетрадки.
#
# Лучше всегда явно ограничивать количество обрабатываемых значений.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментария студента</b></font>
#
# Исправила. Теперь выводиться только первые 5 строк.
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#     <b>v2</b> 👍 </div>

# %%
#Чтобы нормализовать значения в наборе данных между 0 и 1, будем использовать эту
#формулу: zi = (x i – мин(х)) / (макс(х) – мин(х))'''

def norn (row):
    row['expert_score'] = (row['agg']- 1)/(4-1)
    return row

df_expert = df_expert.apply(norn, axis=1)
df_expert
# Out:
#                           image                     query_id  agg  \
# 0     1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2    1
# 1     1056338697_4f7d7ce270.jpg  2718495608_d8533e3ac5.jpg#2    1
# 2     1056338697_4f7d7ce270.jpg  3181701312_70a379ab6e.jpg#2    1
# 3     1056338697_4f7d7ce270.jpg  3207358897_bfa61fa3c6.jpg#2    2
# 4     1056338697_4f7d7ce270.jpg  3286822339_5535af6b93.jpg#2    1
# ...                         ...                          ...  ...
# 5817   997722733_0cb5439472.jpg  2981702521_2459f2c1c4.jpg#2    1
# 5818   997722733_0cb5439472.jpg  2985679744_75a7102aab.jpg#2    1
# 5819   997722733_0cb5439472.jpg  3150742439_b8a352e1e0.jpg#2    1
# 5820   997722733_0cb5439472.jpg  3375070563_3c290a7991.jpg#2    1
# 5821   997722733_0cb5439472.jpg   486917990_72bd4069af.jpg#2    3
#
#       expert_score
# 0         0.000000
# 1         0.000000
# 2         0.000000
# 3         0.333333
# 4         0.000000
# ...            ...
# 5817      0.000000
# ...

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  👍👍👍 за простое и красивое линейное преобразование </div>

# %% [markdown]
# ***Агрегация оценок краудсорсинговой компании***

# %%
#посмотрим на данные

df_crowd.head()
# Out:
#                        image                     query_id  share_pos  \
# 0  1056338697_4f7d7ce270.jpg  1056338697_4f7d7ce270.jpg#2        1.0
# 1  1056338697_4f7d7ce270.jpg   114051287_dd85625a04.jpg#2        0.0
# 2  1056338697_4f7d7ce270.jpg  1427391496_ea512cbe7f.jpg#2        0.0
# 3  1056338697_4f7d7ce270.jpg  2073964624_52da3a0fc4.jpg#2        0.0
# 4  1056338697_4f7d7ce270.jpg  2083434441_a93bc6306b.jpg#2        0.0
#
#    count_pos  count_neg
# 0          3          0
# 1          0          3
# 2          0          3
# 3          0          3
# 4          0          3

# %%
#изучим обущую информацию

df_crowd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47830 entries, 0 to 47829
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   image      47830 non-null  object
#  1   query_id   47830 non-null  object
#  2   share_pos  47830 non-null  float64
#  3   count_pos  47830 non-null  int64
#  4   count_neg  47830 non-null  int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 1.8+ MB

# %%
#посмотрим какие есть доли исполнителей, подверживших, что текст соответсвует картинке

df_crowd['share_pos'].unique()
# Out:
# array([1.        , 0.        , 0.33333333, 0.66666667, 0.25      ,
#        0.6       , 0.2       , 0.5       , 0.4       , 0.75      ,
#        0.16666667, 0.8       ])

# %% [markdown]
# ***Объединим оценки***

# %%
#объединим оценки

df_scores = pd.merge(df_expert, df_crowd, how='outer', on=['image', 'query_id'])

df_scores
# Out:
#                            image                     query_id  agg  \
# 0      1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2  1.0
# 1      1056338697_4f7d7ce270.jpg  2718495608_d8533e3ac5.jpg#2  1.0
# 2      1056338697_4f7d7ce270.jpg  3181701312_70a379ab6e.jpg#2  1.0
# 3      1056338697_4f7d7ce270.jpg  3207358897_bfa61fa3c6.jpg#2  2.0
# 4      1056338697_4f7d7ce270.jpg  3286822339_5535af6b93.jpg#2  1.0
# ...                          ...                          ...  ...
# 51318   997722733_0cb5439472.jpg   543007912_23fc735b99.jpg#2  NaN
# 51319   997722733_0cb5439472.jpg   544576742_283b65fa0d.jpg#2  NaN
# 51320   997722733_0cb5439472.jpg   872622575_ba1d3632cc.jpg#2  NaN
# 51321   997722733_0cb5439472.jpg   888425986_e4b6c12324.jpg#2  NaN
# 51322   997722733_0cb5439472.jpg   997722733_0cb5439472.jpg#2  NaN
#
#        expert_score  share_pos  count_pos  count_neg
# 0          0.000000   0.000000        0.0        3.0
# 1          0.000000   0.000000        0.0        3.0
# ...

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  Отлично, вижу ты решила выполнить соединение через outer и  используешь собраные даные по максимуму. </div>

# %%
#агрегируем оценки людей и экспертов c помощью функции

def score_aggregate(row) -> object:

    if np.isnan(row['expert_score']):
        row['score'] = row['share_pos']
    elif np.isnan(row['share_pos']):
        row['score'] = row['expert_score']
    else:
        row['score'] = row['expert_score'] * 0.6 + row['share_pos'] * 0.4

    return row

df_scores = df_scores.apply(score_aggregate, axis=1)

# %%
#посмотрим получившуюся таблицу

df_scores.head()
# Out:
#                        image                     query_id  agg  expert_score  \
# 0  1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2  1.0      0.000000
# 1  1056338697_4f7d7ce270.jpg  2718495608_d8533e3ac5.jpg#2  1.0      0.000000
# 2  1056338697_4f7d7ce270.jpg  3181701312_70a379ab6e.jpg#2  1.0      0.000000
# 3  1056338697_4f7d7ce270.jpg  3207358897_bfa61fa3c6.jpg#2  2.0      0.333333
# 4  1056338697_4f7d7ce270.jpg  3286822339_5535af6b93.jpg#2  1.0      0.000000
#
#    share_pos  count_pos  count_neg     score
# 0        0.0        0.0        3.0  0.000000
# 1        0.0        0.0        3.0  0.000000
# 2        NaN        NaN        NaN  0.000000
# 3        NaN        NaN        NaN  0.333333
# 4        NaN        NaN        NaN  0.000000

# %%
#удалим лишние столбцы

df_scores = df_scores.drop(columns=['agg','expert_score','share_pos', 'count_pos', 'count_neg'])
df_scores
# Out:
#                            image                     query_id     score
# 0      1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2  0.000000
# 1      1056338697_4f7d7ce270.jpg  2718495608_d8533e3ac5.jpg#2  0.000000
# 2      1056338697_4f7d7ce270.jpg  3181701312_70a379ab6e.jpg#2  0.000000
# 3      1056338697_4f7d7ce270.jpg  3207358897_bfa61fa3c6.jpg#2  0.333333
# 4      1056338697_4f7d7ce270.jpg  3286822339_5535af6b93.jpg#2  0.000000
# ...                          ...                          ...       ...
# 51318   997722733_0cb5439472.jpg   543007912_23fc735b99.jpg#2  0.000000
# 51319   997722733_0cb5439472.jpg   544576742_283b65fa0d.jpg#2  0.333333
# 51320   997722733_0cb5439472.jpg   872622575_ba1d3632cc.jpg#2  1.000000
# 51321   997722733_0cb5439472.jpg   888425986_e4b6c12324.jpg#2  0.000000
# 51322   997722733_0cb5439472.jpg   997722733_0cb5439472.jpg#2  0.666667
#
# [51323 rows x 3 columns]

# %%
df_scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51323 entries, 0 to 51322
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   image     51323 non-null  object
#  1   query_id  51323 non-null  object
#  2   score     51323 non-null  float64
# dtypes: float64(1), object(2)
# memory usage: 1.6+ MB

# %%
#присоедним экспертные оценки в обучающей базе данных

df_train = pd.merge(df_train, df_scores, how='outer', on=['image', 'query_id'])

df_train
# Out:
#                            image                     query_id  \
# 0      1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2
# 1      1262583859_653f1469a9.jpg  2549968784_39bfbe44f9.jpg#2
# 2      2447284966_d6bbdb4b6e.jpg  2549968784_39bfbe44f9.jpg#2
# 3      2549968784_39bfbe44f9.jpg  2549968784_39bfbe44f9.jpg#2
# 4      2621415349_ef1a7e73be.jpg  2549968784_39bfbe44f9.jpg#2
# ...                          ...                          ...
# 51318   997722733_0cb5439472.jpg   543007912_23fc735b99.jpg#2
# 51319   997722733_0cb5439472.jpg   544576742_283b65fa0d.jpg#2
# 51320   997722733_0cb5439472.jpg   872622575_ba1d3632cc.jpg#2
# 51321   997722733_0cb5439472.jpg   888425986_e4b6c12324.jpg#2
# 51322   997722733_0cb5439472.jpg   997722733_0cb5439472.jpg#2
#
#                                               query_text     score
# 0      A young child is wearing blue goggles and sitt...  0.000000
# 1      A young child is wearing blue goggles and sitt...  0.000000
# ...

# %%
#заполняем пропуски в графе query_text  по query_id


to_add_text = df_train[df_train['query_text'].notna()]

def add_text(row):

    if pd.isnull(row['query_text']):
        texts = to_add_text[to_add_text['query_id'] == row['query_id']]['query_text']
        if len(texts) > 0:
            row['query_text'] = texts.iloc[0]

    return row

df_train = df_train.apply(add_text, axis=1)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51323 entries, 0 to 51322
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   image       51323 non-null  object
#  1   query_id    51323 non-null  object
#  2   query_text  50214 non-null  object
#  3   score       51323 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 2.0+ MB

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Очень неочевидный шаг... у тебя было почти 50 000 оцененных пар изображение/текст... Но после inner ты оставила всего 5767 пар...  Потеряно 90% данных. А всего то нужно было добавить расшифровку текста по его id, что сделать очень просто.
#
# Получается ты зря добавляла краудсорс оценки, если все равно их удалила. Да еще и помехи внесла в оценку target
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментария студента</b></font>
#
# Исправила. Добавила расшифровку текста по его query_id.
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#     <b>v2</b> 👍 </div>

# %%
#удалим пропуски в тренировочной базе, где нет описания текста запроса

df_train = df_train.dropna(subset=['query_text'])

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50214 entries, 0 to 51322
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   image       50214 non-null  object
#  1   query_id    50214 non-null  object
#  2   query_text  50214 non-null  object
#  3   score       50214 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 1.9+ MB

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  ОК, получен итоговый датафрейм, с которым мы можем продолжать работу </div>

# %% [markdown]
# ***Выводы по обработке оценок экспертов и краудсорсинга***
#
# Эксперты ставят оценки по шкале от 1 до 4, где 1 — изображение и запрос совершенно не соответствуют друг другу, 2 — запрос содержит элементы описания изображения, но в целом запрос тексту не соответствует, 3 — запрос и текст соответствуют с точностью до некоторых деталей, 4 — запрос и текст соответствуют полностью. Всего было 3 мненяи по каждому запросу. Мы в итоге выбрали одно из наиболее часто встречающихся, если все три оценки были разные, то оценка эксперта считалась равно 1, что соответствовало тому, что изображение и запрос совершенно не соответсвуют друг другу. Далее полученная итоговая оценка была нормализована в диапазон от 0 до 1.
#
# Оценку краудсорсинга брали по колонке 'share_pos', что показывало долю людей, подтвердивших, что описание соответствует изображению.
# Далее мы аггрегировали 2 вида оценок по принциау:
# 1) если не оценок экспертов, то ставим оценку краудсорсинга
# 2) если не оценок краудсорсинга, то ставим оценку экспертов
# 3) если есть обе оценки, то оценки объединили по принципу: оценка эксперта принимается с коэффициентом 0.6, а крауда — с коэффициентом 0.4.
#
#
# После чего все лишние столбцы удалили. Пропусков данных в получившейся таблице нет. Наша тренировочная база в итоге в размере  именилсь: была 5822 строк, а стала 50214. И добавилась новая колонка 'score', где указана аггрегированная оценка экспертов.

# %% [markdown]
# ## 2. Проверка данных
#
# В некоторых странах, где работает ваша компания, действуют ограничения по обработке изображений: поисковым сервисам и сервисам, предоставляющим возможность поиска, запрещено без разрешения родителей или законных представителей предоставлять любую информацию, в том числе, но не исключительно тексты, изображения, видео и аудио, содержащие описание, изображение или запись голоса детей. Ребёнком считается любой человек, не достигший 16 лет.
#
# В вашем сервисе строго следуют законам стран, в которых работают. Поэтому при попытке посмотреть изображения, запрещённые законодательством, вместо картинок показывается дисклеймер:
#
# > This image is unavailable in your country in compliance with local laws
# >
#
# Однако у вас в PoC нет возможности воспользоваться данным функционалом. Поэтому все изображения, которые нарушают данный закон, нужно удалить из обучающей выборки.

# %% [markdown]
# Чтобы удалить нелегальный контент мы воспользуемся текстовыми описаниями файлов.
#
# Для этого составим список слов, где есть упоминание о детях, для поиска нелегального контента.
#
# Очистим, токенизируем и лемматизируем текст. Отметим в обучающем наборе фото подлежащие блокировке и удалим их.

# %%
lemmatize = nltk.WordNetLemmatizer()
SEED = 31416
BLOCK = ['teenage', 'baby', 'child', 'teenager', 'girl', 'boy', 'kid']

#очищаем текст и превращаем в список лемм

def get_lemmas(text):

    text = re.sub(r"(?:\n|\r)", " ", text) #удаляем символы
    text = re.sub('[^a-zA-Z]', ' ', text).lower() # удаляем неалфавитные символы, приводим к нижнему регистру
    text = nltk.word_tokenize(text, language = 'english') # токенизируем слова
    text = [lemmatize.lemmatize(word) for word in text] # лемматирзируем слова

    return text

#отмечаем тексты для блокирования

def cleaning(row):

    text = get_lemmas(row['query_text'])
    if [i for i in text if i in BLOCK]:
        row['to_block'] = 1
    else:
        row['to_block'] = 0

    return row

# %%
# %time

#применим функция для отметки текста для блокирования
df_train= df_train.apply(cleaning, axis =1)
# Out:
# Wall time: 0 ns

# %%
#посмотрим получившиеся данные

df_train.head()
# Out:
#                        image                     query_id  \
# 0  1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2
# 1  1262583859_653f1469a9.jpg  2549968784_39bfbe44f9.jpg#2
# 2  2447284966_d6bbdb4b6e.jpg  2549968784_39bfbe44f9.jpg#2
# 3  2549968784_39bfbe44f9.jpg  2549968784_39bfbe44f9.jpg#2
# 4  2621415349_ef1a7e73be.jpg  2549968784_39bfbe44f9.jpg#2
#
#                                           query_text  score  to_block
# 0  A young child is wearing blue goggles and sitt...    0.0         1
# 1  A young child is wearing blue goggles and sitt...    0.0         1
# 2  A young child is wearing blue goggles and sitt...    0.2         1
# 3  A young child is wearing blue goggles and sitt...    1.0         1
# 4  A young child is wearing blue goggles and sitt...    0.0         1

# %% [markdown]
# ***Удаляем фото с детьми из найденных 285 запрещенных изображений***

# %%
#удалим последние 2 символв в графе g=query_id, чтобы получить список "плохих изображений"

df_train['image2'] = df_train['query_id'].str.replace('#2', '')

# %%
df_train.head()
# Out:
#                        image                     query_id  \
# 0  1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2
# 1  1262583859_653f1469a9.jpg  2549968784_39bfbe44f9.jpg#2
# 2  2447284966_d6bbdb4b6e.jpg  2549968784_39bfbe44f9.jpg#2
# 3  2549968784_39bfbe44f9.jpg  2549968784_39bfbe44f9.jpg#2
# 4  2621415349_ef1a7e73be.jpg  2549968784_39bfbe44f9.jpg#2
#
#                                           query_text  score  to_block  \
# 0  A young child is wearing blue goggles and sitt...    0.0         1
# 1  A young child is wearing blue goggles and sitt...    0.0         1
# 2  A young child is wearing blue goggles and sitt...    0.2         1
# 3  A young child is wearing blue goggles and sitt...    1.0         1
# 4  A young child is wearing blue goggles and sitt...    0.0         1
#
#                       image2
# 0  2549968784_39bfbe44f9.jpg
# 1  2549968784_39bfbe44f9.jpg
# 2  2549968784_39bfbe44f9.jpg
# 3  2549968784_39bfbe44f9.jpg
# 4  2549968784_39bfbe44f9.jpg

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментария студента V3</b></font>
#
# Дмитрий, посмотри, пожалуста, что делаю не так в коде ниже.
#
# Как ты рекомендовал я столбце query_id убрала 2 последних символа и получила список изобрадений, кторый надо удалить.
#
#
#
# </div>

# %%
#создадим список фото, на которых упомянуты дети
df_support = df_train[df_train['to_block'] == 1]

#удалим ненужные столбцы
df_support = df_support.drop(columns=['image','query_text','score', 'query_id'])

# %%
df_support = df_support.drop_duplicates().reset_index(drop=True) 
df_support.head()
# Out:
#    to_block                     image2
# 0         1  2549968784_39bfbe44f9.jpg
# 1         1  2718495608_d8533e3ac5.jpg
# 2         1  3545652636_0746537307.jpg
# 3         1  1714316707_8bbaa2a2ba.jpg
# 4         1  2140182410_8e2a06fbda.jpg

# %%
#переименуем колонки, чтобы таблицы можно было соединить
df_support.columns = df_support.columns.str.replace('image2', 'image')
df_support.columns = df_support.columns.str.replace('to_block', 'to_block2')
df_support.head()
# Out:
#    to_block2                      image
# 0          1  2549968784_39bfbe44f9.jpg
# 1          1  2718495608_d8533e3ac5.jpg
# 2          1  3545652636_0746537307.jpg
# 3          1  1714316707_8bbaa2a2ba.jpg
# 4          1  2140182410_8e2a06fbda.jpg

# %%
df_support.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 285 entries, 0 to 284
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   to_block2  285 non-null    int64
#  1   image      285 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 4.6+ KB

# %% [markdown]
# ***Нам надо удалитить из датафрейма 285 изобраэжений***

# %%
#соединим таблицы

df_train = df_train.merge(df_support, how='left', on=['image'])

df_train.head()
# Out:
#                        image                     query_id  \
# 0  1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2
# 1  1262583859_653f1469a9.jpg  2549968784_39bfbe44f9.jpg#2
# 2  2447284966_d6bbdb4b6e.jpg  2549968784_39bfbe44f9.jpg#2
# 3  2549968784_39bfbe44f9.jpg  2549968784_39bfbe44f9.jpg#2
# 4  2621415349_ef1a7e73be.jpg  2549968784_39bfbe44f9.jpg#2
#
#                                           query_text  score  to_block  \
# 0  A young child is wearing blue goggles and sitt...    0.0         1
# 1  A young child is wearing blue goggles and sitt...    0.0         1
# 2  A young child is wearing blue goggles and sitt...    0.2         1
# 3  A young child is wearing blue goggles and sitt...    1.0         1
# 4  A young child is wearing blue goggles and sitt...    0.0         1
#
#                       image2  to_block2
# 0  2549968784_39bfbe44f9.jpg        NaN
# 1  2549968784_39bfbe44f9.jpg        NaN
# 2  2549968784_39bfbe44f9.jpg        1.0
# ...

# %%
#удалим ненужные столбец image 2 и to_block	, который мы создавали для таблица df_support
df_train = df_train.drop(columns=['image2', 'to_block'])

# %%
#посмотрим какие описания были заблокированы

print(df_train[df_train['to_block2'] == 1]['query_text'].unique())
# Out:
# ['A young child is wearing blue goggles and sitting in a float in a pool .'
#  'A girl wearing a yellow shirt and sunglasses smiles .'
#  'A woman plays with long red ribbons in an empty square .'
#  'A soccer ball is above the head of a man wearing black shorts and red and black striped shirt .'
#  'A young boy dressed in a red uniform kicks the soccer ball on the field as another child in blue watches from behind .'
#  'A man and woman look back at the camera while standing in front of a red art structure .'
#  'A white dog jumps to catch a blue ball in a living room .'
#  'A little boy shakes the snow off of a tree .'
#  'The kid is on a float in the snow .'
#  'Two long-haired puppy dogs have a romp in the snow .'
#  'A little girl wearing sunglasses puts her feet into the kitchen sink .'
#  'Snowboarder in the air performing a stunt .'
#  'A dog runs through the deep snow .'
#  'A dog wearing a collar jumping from a platform .'
#  'A crowd of people at an outdoor event'
# ...

# %% [markdown]
# В тексте встречаются запрещенные слова, делаем вывод, что функция для блокировки запрещенных слов работает.

# %%
#посмотрим изображения, заблокированные законодательством, где упомянуты дети

samples = list(df_train[df_train['to_block2'] == 1]['query_id'].sample(10))
samples = [i[:-2] for i in samples]

fig = plt.figure(figsize=(10,10))
for i in range(10):
    fig.add_subplot(4, 4, i+1)
    image = Image.open(Path(PATH, 'train_images', samples[i]))
    plt.imshow(image)
    plt.xticks([])
    plt.yticks([])
    plt.tight_layout()

# %% [markdown]
# На заблокированных изображениях также везде встречаются дети.

# %%
#посмотрим сколько у нас изобрадений оказалось заблокировано и сколько останется после их удаления
df_train['to_block2'].value_counts()
# Out:
# 1.0    14109
# Name: to_block2, dtype: int64

# %%
#удалим все фото, где встречаются запрещенные слова
df_train.drop(df_train[df_train['to_block2'] == 1].index, inplace=True, errors='ignore')

#удалим ненужный теперь столбец
df_train.drop(columns='to_block2', inplace=True, errors='ignore')

# %%
#посмотрим сколько данных в обучающей выборке осталось после удаления

df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36105 entries, 0 to 50213
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   image       36105 non-null  object
#  1   query_id    36105 non-null  object
#  2   query_text  36105 non-null  object
#  3   score       36105 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 1.4+ MB

# %%
#посмотрим сколько уникальных изображениц осталось
len(df_train['image'].unique())
# Out:
# 715

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
#
# Ты удалила комментарии, в которых были запрещенные слова. Но наша задача убрать изображения, содержащие детей. Есть два способа сделать это:
#
#  - Определить список плохих изображений, как изображения удовлетворяющие условиям:
#     - Комментарий содержит плохие слова
#     - <b>Оценка соответствия комментария и изображения выше порога.</b>
#  - Удалить из нашего датасета все пары "изображение/описание" с плохими изображениями.
#
#
# И второй, очень красивый способ. Он основан на том, что `query_id` содержит в с себе имя изображения, для которого он был написан (такая пасхалочка от авторов датасета).
#
#  - Определить список плохих комментариев
#  - У `query_id`  плохих комментариев отрезать два последних символа и получим список плохих изображений.
#
#
# Ты даже использовала это свойство, когда показывала изображения с детьми и проверила, что они все правильные.
#
# -----
#
# Обычно этот комментарий желтый. Но этот блок в таком виде мне очень хорошо знаком, включая ошибки. Поэтому в качестве дополнительного задания пожалйста исправь ошибку в очистке детских изображений.
#
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментария студента</b></font>
#
# Удалила из датасете данные, где по оценке экспертов нет совпаления изображения и текста. Код в той же ячейке, что удаление строк, где есть упоминание детей.
#
# Так как при загрузке изобрадений для его векторизации мы  сслывемся на dataframe=df_train то у нас получется векторизируются только изобрадения, соответствующие данным в датасете df_train, а там у неас удалены данные, где ест упоминание детей и  оценки выше порога соответствия.
#
#
#
#
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# <b>v2</b>
#
# Ты удалила почти все записи из нашего датасета, что принципиально неверно. При корректной чистке должно уйти около 30% записей.
#
# В вашей когорте я вижу неожиданную ошибку, которая никогда не встерчалась раньше - вы удаляете и записи, где есть описания с детьми и записи,где есть изображения с детьми. Но так мы удаляе слишком много, около половины записей.
#
# Поэтому прошу тебя выполнить очень простое действие и не усложнять:
#
#  - найти список изображений, где есть дети
#  - из всех 50 тысяч записеей удалить те записи, где есть изображения с детьми
#
# При правильной последоательности действий должно получиться около 35_000 изображений.
#
#
#
#
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментария студента</b></font>
#
# Скорректировала код и удалила из датасета записи и изображения с детьми, осталось в итоге 36125 записей. Это оптимальный вариант.
#     Пробовала гипотезу, что в тексте слова запрещенные не всречаются, а вот на фото дети есть и это можно узнать по одинаковому номеру в графе image, но тогда удалить надо 35994 фото. Поэтому оставила это варианет.
#     Если снова не так, то я просто не понимаю как тогда искать запрещенные фото иначе. Подскажи, пожалуста.
#
#
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментария студента V3</b></font>
#
# !!!! Дмитрий в отправленной тобой версии нет комментарией (V3).Видимо, отправлена не та версия.Исправила еще раз в итоге осталось 29 246 значений. Описание действий выше в таком же комментарии.
#
#     Код ниже не перезапускала, так как на жто уходит до 4 часов  меня. И замечаний по ним нет.
#     Замечания у тебя были только по удалению изображений с детьми.
#
#
#
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# <b>v3</b>
#
# Юля, привет... Действительно я отправил не ту терадку.. Прошу прощения
#
# ---------
#
# Давай вернемся к изначальной рекомендации, которую я тебе написал:
#
#
#  - Создать полный список комментариев, в которых есть упоминание детей.
#  - У query_id таких комментариев отрезать два последних симпола, получится список изображений с детьми.
#
# Доработки кода, которые нужно сделать минимальные.
#
#  - оставляем создание колонки 'to_block'
#  - ты можешь доработать вот этот кусок кода
#
#
#     ```python
#     samples = list(df_train[df_train['to_block'] == 1]['query_id'].sample(10))
#     samples = [i[:-2] for i in samples]
#     ```
#
#
# Внимательно изучи его. В этом куске кода создается список из 10 изображений, в которых есть дети. Но нам нужно найти все изображения с детьми.
#
#  - а дальше, когда ты получишь список изображений с детьми нужно просто удалить все записи, в которых есть такие изображения. Можно сделать это например через query
#
# Я честно стараюсь объяснить тебе что именно нужно сделать. Следующим шагом будет только написание кода.
#
#
# </div>

# %% [markdown]
# ***Выводы по проверке данных:***
#
# Мы нашли и удалили из обучающей выборки все запрещенные данные, где содержится информация (текст/изображение) о детях.

# %% [markdown]
# ## 3. Векторизация изображений
#
# Перейдём к векторизации изображений.
#
# Самый примитивный способ — прочесть изображение и превратить полученную матрицу в вектор. Такой способ нам не подходит: длина векторов может быть сильно разной, так как размеры изображений разные. Поэтому стоит обратиться к свёрточным сетям: они позволяют "выделить" главные компоненты изображений. Как это сделать? Нужно выбрать какую-либо архитектуру, например ResNet-18, посмотреть на слои и исключить полносвязные слои, которые отвечают за конечное предсказание. При этом можно загрузить модель данной архитектуры, предварительно натренированную на датасете ImageNet.

# %%
#напишем функции загрузчиков изображений


def load_train(path=PATH):


    train_datagen = ImageDataGenerator(rescale=1/255.)
    train_gen_flow = train_datagen.flow_from_dataframe(
        dataframe=df_train,
        directory=Path(path, 'train_images'),
        x_col='image',
        y_col='score',
        target_size=(224, 224),
        batch_size=16,
        class_mode='input',
        shuffle=False,
        seed=SEED)

    return train_gen_flow

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# Вот здесь проблема, и она заключается в том, что  у flow_from_dataframe есть дефолтный аргумент shuffle=True, а значит выдаваемые им изображения перемешиваются, и идут совсем не в том порядке,как в датфрейме.  Как следствие мы получаем эмбеддинги не соответствующие изображениям в датафрейме.</div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментария студента</b></font>
#
# Исправила. Установила shuffle=False.
#
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#     <b>v2</b> 👍 </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Модель ResNEt обучалась на изображениях размером 224х224. Подавая изображения других размеров ты получаешь эмбеддинги гораздо более низкого качества.
#
#
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментария студента</b></font>
#
# Исправила. Установила размер 224*224.
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#     <b>v2</b> 👍 </div>

# %%
#выведем полученные картинки

flow_train = load_train()
features, target = next(flow_train)

fig = plt.figure(figsize=(13,10))
for i in range(10):
    fig.add_subplot(2, 5, i+1)
    plt.imshow(features[i])
    plt.xticks([])
    plt.yticks([])
    plt.tight_layout()
plt.show()

# %%
#зададим модель

def create_model(input_shape=(256, 256, 3)):

    backbone = ResNet50(input_shape=input_shape,
                        weights='imagenet',
                        include_top=False)
    model = Sequential()
    model.add(backbone)
    model.add(GlobalAveragePooling2D())
    optimizer = Adam(learning_rate=1e-3)
    model.compile(optimizer=optimizer, loss='mean_squared_error',
                  metrics=['mean_absolute_error'])

    return model

# %%
#эмбеддинги,превращаем данные в вектор

def vectorize_pictures(model, train_data):

    predictions = model.predict(train_data)

    return predictions

# %%
# %%time

pict_embeds = vectorize_pictures(create_model(), load_train())

# %%
pict_embeds.shape

# %%
pict_embeds

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  Отлично, вектра для изображений получены👍 </div>

# %% [markdown]
# ***Вывод:***
#
# Картинки векторизированы. Переходим к тексту.

# %% [markdown]
# ## 4. Векторизация текстов
#
# Следующий этап — векторизация текстов. Вы можете поэкспериментировать с несколькими способами векторизации текстов:
#
# - tf-idf
# - word2vec
# - \*трансформеры (например Bert)
#
# \* — если вы изучали трансформеры в спринте Машинное обучение для текстов.

# %% [markdown]
# Следующий этап — векторизация текстов. Для векторизации тектов применим трансформер BERT из библиоетки Keras-NLP.

# %%
#загрузим трансформер BERT base cased EN без классифицирующей головы

bert = keras_nlp.models.BertBackbone.from_preset('bert_base_en')

# %%
#загрузим препроцессор для трансформера

preprocessor = keras_nlp.models.BertPreprocessor.from_preset('bert_base_en')

# %%
#напишем функцию для получения эмбеддингов

def vectorize_text(model, data, preprocessor=preprocessor, batch_size=32, bar=True, verbose=0) -> np.array:

#преобразуем тексты в словарь токенов, масок и паддингов

    embeddings = []
    tokenized = preprocessor(data)

    if bar:
        for i in notebook.tqdm(range(tokenized['token_ids'].shape[0] // batch_size + 1)):

            tokens = tokenized['token_ids'][batch_size*i:batch_size*(i+1)]
            token_types = tokenized['segment_ids'][batch_size*i:batch_size*(i+1)]
            mask = tokenized['padding_mask'][batch_size*i:batch_size*(i+1)]

            batch = {'token_ids' : tokens,
                    'segment_ids' : token_types,
                    'padding_mask' : mask}

            batch_embeddings = model.predict(batch, verbose=verbose)

            embeddings.append(batch_embeddings['pooled_output'])

    else:
        for i in range(tokenized['token_ids'].shape[0] // batch_size + 1):

            tokens = tokenized['token_ids'][batch_size*i:batch_size*(i+1)]
            token_types = tokenized['segment_ids'][batch_size*i:batch_size*(i+1)]
            mask = tokenized['padding_mask'][batch_size*i:batch_size*(i+1)]

            batch = {'token_ids' : tokens
                     
                     
                     
                    'segment_ids' : token_types,
                    'padding_mask' : mask}

            batch_embeddings = model.predict(batch, verbose=verbose)

            embeddings.append(batch_embeddings['pooled_output'])

    return np.concatenate(embeddings)

# %%
#преобразуем тексты для подачи в функцию

text = list(df_train['query_text'])

# %%
# %%time

text_embeds = vectorize_text(model=bert, data=text)

# %%
text_embeds.shape

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Отлично,полученные векторные представления для текстов описаний с помощью BERT </div>

# %% [markdown]
# ## 5. Объединение векторов
#
# Подготовьте данные для обучения: объедините векторы изображений и векторы текстов с целевой переменной.

# %%
#Подготовим данные для обучения: объединим векторы изображений и векторы текстов с целевой переменной.


X = np.concatenate((pict_embeds, text_embeds), axis=1)
count_tf_idf = TfidfVectorizer(stop_words=stopwords)

# %%
#выделим целевой признак

y = np.array(df_train['score'])
y.shape

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  Вектора, полученные из текста и изображения объеденены👍 </div>

# %% [markdown]
# ***Вывод:***
#
# Признаки и целовой признак выделены. Векторизацию текстов проведем через pipeine. Можно приступать к обучению моделей.

# %% [markdown]
# ## 6. Обучение модели предсказания соответствия
#
# Для обучения разделите датасет на тренировочную и тестовую выборки. Простое случайное разбиение не подходит: нужно исключить попадание изображения и в обучающую, и в тестовую выборки.
# Для того чтобы учесть изображения при разбиении, можно воспользоваться классом [GroupShuffleSplit](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GroupShuffleSplit.html) из библиотеки sklearn.model_selection.
#
# Код ниже разбивает датасет на тренировочную и тестовую выборки в пропорции 7:3 так, что строки с одинаковым значением 'group_column' будут содержаться либо в тестовом, либо в тренировочном датасете.
#
# ```
# from sklearn.model_selection import GroupShuffleSplit
# gss = GroupShuffleSplit(n_splits=1, train_size=.7, random_state=42)
# train_indices, test_indices = next(gss.split(X=df.drop(columns=['target']), y=df['target'], groups=df['group_column']))
# train_df, test_df = df.loc[train_indices], df.loc[test_indices]
#
# ```
#
# Какую модель использовать — выберите самостоятельно. Также вам предстоит выбрать метрику качества либо реализовать свою.

# %%
RANDOM_STATE = 123455
#разобьем данные на тренировочную и тестовую выборки

gss = GroupShuffleSplit(n_splits=1, train_size=.8, random_state=RANDOM_STATE)
train_indices, test_indices = next(gss.split(X=X, y=y, groups=df_train['image']))

X_train, X_valid = X[train_indices], X[test_indices]

y_train, y_valid = y[train_indices], y[test_indices]

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Отлично, благодаря использованию GroupShuffleSplit ты исключаешь попадание одного изображения в обучающий и валидационный наборы.</div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Только давай разберемся с выборками. Финальное тестирование (визуальное) мы делаем на отложенной выборке. Поэтому выборка,которую ты сейчас отделил играет роль валидационной. Есть смысл в её названии использовать слово valid а не test</div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментария студента</b></font>
#
# Исправила. Переименвоал выборку в valid.
#
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#     <b>v2</b> 👍 </div>

# %%
#проведем масштабирование

scaler = StandardScaler().fit(X_train)
X_train = scaler.transform(X_train)
X_valid = scaler.transform(X_valid)

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  👍 Да, масштабировать данные перед подачей в нейронку или линейную модель обязательно </div>

# %%
X_train

# %% [markdown]
# ### Обучение моделей

# %% [markdown]
# Обучим 2 модели и выберем из них лучшую. В качестве метрики качества будет использована RMSE, так как показатели говорят нам, насколько точны наши прогнозы и какова величина отклонения от фактических значений.

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# В этом задании требуется выбрать основную метрику, которую ты будешь оптимизировать. Пожаулуйста обоснуй свой выбор.  </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментария студента</b></font>
#
# Выбор метрики обосновала выше.
#
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#     <b>v2</b> 👍 </div>

# %% [markdown]
# ***Модель №1  - Линейная регрессия***

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Мы решаем новую задачу и не знаем, наксколько хороши наши метрики и наши модели. Поэтому советую начать с бейзлайна - константной модели (можешь взять простой DummyRegressor).</div>

# %%
# %%time

#модель линейное регрессии

model = LinearRegression(n_jobs=-1)
model.fit(X_train, y_train)
score = cross_val_score(
    model, X_train, y_train, groups=df_train['image'].loc[train_indices],
    scoring='neg_root_mean_squared_error',
    cv=GroupShuffleSplit(random_state=RANDOM_STATE)
).mean()
abs(score).round(decimals=3)

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
# Как я писал тебе выше, у нас есть валидационная выборка. Поэтому не стоит таратить время на кросс-валидацию.</div>

# %%
#проверим на тестовоу выборке

pred = model.predict(X_valid)
mean_squared_error(y_valid, pred, squared=False).round(decimals=3)

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Видно что линейная модель дико переобучилась. Урок для нас - использовтаь регуляризацию для нейронки. Также можно попроловать линейную модель с регуляризацией (Ridge/Lasso).</div>

# %% [markdown]
# ***Модель №2  - Полносвязная нейронная сеть***

# %%
#создадим трехслойную нейронную сеть

NN = Sequential()
NN.add(Dense(2816, input_shape=(2816,), activation='relu'))
NN.add(BatchNormalization())
NN.add(Dense(256, activation='relu'))
NN.add(BatchNormalization())
NN.add(Dense(1, activation='relu'))

optimizer = Adam(learning_rate=1e-5)

NN.compile(optimizer=optimizer, loss='mean_squared_error',
            metrics=[tf.keras.metrics.RootMeanSquaredError()])

NN.build()

NN.summary()

# %%
NN.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=32, epochs=20,
    verbose=2, shuffle=True
    )

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  👍 </div>

# %% [markdown]
# ***Выводы по моделям:***
#
# Мы протестировали работу 2 моделей - Линейной регрессии и NN.
# Модель NN показала лучшей результат, ее RMSE = 0.2331, а Линейной регресси -  2907.44.
#
# Поэтому для тестирования будем использовать модель NN

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  👍 </div>

# %% [markdown]
# ## 7. Тестирование модели
#
# Настало время протестировать модель. Для этого получите эмбеддинги для всех тестовых изображений из папки `test_images`, выберите случайные 10 запросов из файла `test_queries.csv` и для каждого запроса выведите наиболее релевантное изображение. Сравните визуально качество поиска.

# %%
#cоздадим загрузчик тестовых изображений

def load_test(path=PATH):

    train_datagen = ImageDataGenerator(rescale=1/255.)
    train_gen_flow = train_datagen.flow_from_dataframe(
        dataframe=df_images,
        directory=Path(path, 'test_images'),
        x_col='image',
        y_col=None,
        target_size=(256, 256),
        batch_size=16,
        class_mode='input',
        shuffle=False,
        seed=SEED)

    return train_gen_flow

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
#
#
# Здесь та же проблема с перемешиванием</div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментария студента</b></font>
#
# Исправила. Установила shuffle=False.
#
#
# </div>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#     <b>v2</b> 👍 </div>

# %% [markdown]
# Получим эмбеддинги тестовых картинок

# %%
# %%time

pict_embeds_test = vectorize_pictures(create_model(), load_test())
pict_embeds_test.shape

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Да, действительно, изображения лучше векторизовать заранее </div>

# %%
#Напишем функцию, принимающую на вход текстовое описание и возвращающую 5 картиной с максимальной предсказанной
#оценкой схожести.

def get_picture(text) -> None:

    '''Проверяем легальность запроса, получаем наиболее похожие картинки,
    если описание среди оригинальных картинок - добавляем последней верную'''

    if [i for i in get_lemmas(text) if i in BLOCK]: #проверяем не нужно ли вывести на экран заглушку
        print('')
        print('-' * 20, text, '-' * 20)
        print('')
        print('This image is unavailable in your country in compliance with local laws.')
        print('')
    else:
        text_embed = vectorize_text(model=bert, data=[text], bar=False) #получаем эмбеддинг текста
        X = np.concatenate(( #объединяем вектора тестовых картинок с эмбеддингом текста
            pict_embeds_test,
            np.resize(text_embed, (pict_embeds_test.shape[0],768))),
            axis=1)
        X = scaler.transform(X)
        predictions = NN.predict(X) #получаем предсказания оценок экспертов
        df = pd.concat((df_images, pd.Series(np.reshape(predictions, (predictions.shape[0],)), name='pred')), axis=1) #добавляем оценки к номерам картинок
        top = list(df.sort_values(by='pred', ascending=False)['image'].head(5)) #получили топ 5 имён файлов с картинками
        top_score = list(df.sort_values(by='pred', ascending=False)['pred'].head(5)) #получили топ 5 оценок

        print('')
        print('-' * 20, text, '-' * 20)
        print('')

        fig = plt.figure(figsize=(15,5)) #выводим на экран 5 наиболее похожих картинок
        plt.rcParams['axes.edgecolor'] = 'black'
        plt.rcParams['axes.linewidth'] = 0
        for i in range(5):
            fig.add_subplot(1, 6, i+1, title=round(top_score[i], 2))
            image = Image.open(Path(PATH, 'test_images', top[i]))
            plt.imshow(image)
            plt.xticks([])
            plt.yticks([])
            plt.tight_layout()

        if text in list(df_queries['query_text']): #если текст был в исходном файле с описаниями - добавляем оригинальную картинку
            plt.rcParams['axes.edgecolor'] = 'green'
            plt.rcParams['axes.linewidth'] = 5
            fig.add_subplot(1, 6, 6)
            image = Image.open(Path(PATH, 'test_images', df_queries.iloc[df_queries[df_queries['query_text'] == text].index[0]]['image']))
            plt.imshow(image)
            plt.xticks([])
            plt.yticks([])
            plt.tight_layout()

        plt.show()

    return None

# %%
#Теперь выберем 10 случайных запросов из файла с тестовыми запросами и посмотрим на результаты.
samples = df_queries.sample(10)
text_test = list(samples['query_text'])
text_test

# %%
for text in text_test:
    get_picture(text)

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Функции написаны и со своей задачей справляются. Принимают на вход текст и находят изображение. Отрабатывают контроль "запрещенного контента".
#
# Да, ты права, к сожалению работают они не очень. И причин тут несколько - мало данных, не очень правильный подход. На мой взгляд более перспективным было бы привести ембеддинги изображений и текстов к одной размерности в одно пространство (через обучаемые слои) и в качестве меры близости использовать косинусное расстояние.
#
# Хотя  в твоем случае есть более очевидная причина - ошибка при векторизации. Фактически изображения были перемешаны при векторизации, поэтому модель училась "на шуме".
# </div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Идеи и альтернативные подходы</b>
#   Если хочешь получить хорошо работающее решение без обучения, то можешь провести эксперимент с нейронной сетью CLIP от OPEN AI (это не обязательно, только если хочешь добиться хороших результатов в этом проекте).
#
#   Про эту нейронку много где написано, но можешь посмотреть например вот здесь  https://habr.com/ru/post/539312/.
#
#   А для написания  реализации наиболее удобной лично для меня оказалась библиотека sbert. https://www.sbert.net/examples/applications/image-search/README.html
#
#
# <hr>
#
# Также неплохо работает следующий подход без предобученных моделей (к тому же легко реализуемый).
#
#
# Вместо того, чтобы подавать на вход модели изображение + текст и получать меру соответствия, поступаем по другому.
#
# На вход модели подаем вектор описания, а на выходе учимся предсказывать вектор изображения.
#
# По поводу метрик тут ситуация следующая. Точно работает следующий подход
#
#   - берем метрику mse, но тогда нужно чтобы модель её уменьшала. А значит в обучении используем только пары заведомо сответствующие друг другу
#
# Можно попробовать использовать косинусное расстояние, она позволяет использовать все данные (если есть соответствие то выдает 1, если нет то 0).
#
# Также можно попробовать усложнить модель, например и изображения и тексты отправлять в пространство размерностью 256 и уже в этом пространстве учиться их "сближать".
#
# По поводу методов векторизации: я бы использовать resnet18 для изображений (размерность эмбеддинга избражения 512) и БЕРТ для текстов (768).
#
# ***
#
# А еще я видел удачный проект, где для векторизации изображений использовалось предсказание Resnet в котором не отключался последний слой. Получился вектор предсказаний верояятности что изображение принадлежит к каждому из 1000 классов Imagenet. И в сочетании с подходом "мешок слов" для текстов это может дать неплохой результа. Такая модель находит людей, собак, машины, снег и т.д.
#
# </div>

# %% [markdown]
# ***ИТОГОВЫЕ ВЫВОДЫ ПО ПРОЕКТУ***
#
# В данной работе проводили эксперимент по разработке поиска референсных фотографий для фотографов, чтобы проверить, что такой проект практически осуществим.
#
# В ходе работы для векторизации изображений мы использовали сеть ResNet50, а для текстовых эмбеддингов BERT base cased EN.
#
# После объединения признаков и выделения целей (экспертные оценки схожести описания и картинок), были исследованы исследовали
# две модели для оценки схожести:
#
#  - LinearRegression
#  - трёхслойную нейронную сеть NN.
#
#
# Для отбора лучшей модели сипользовпл метрику RMSE, ее значение намного лучше было в нейронная сеть,поэтому с ней мы провели тесты.
#
# В конце работы мы была написана функция, которая по тексту возвращает 5 наиболее похожих картинок и протестировали её на предложенном наборе тестовых картинок.
#
# К сожалению выбранный подход не оправдал себя. Лишь в некоторых случаях в топ5 выдачи попадает верная картинка и, чуть чаще, попадают картинки связанные тематически.
#
# В качестве возможных путей для решения можно предложить использовать полный набор картинок из датасета Flickr30k и смену архитектуры решения.

# %% [markdown]
# ## 8. Выводы
#
# - Jupyter Notebook открыт
# - Весь код выполняется без ошибок
# - Ячейки с кодом расположены в порядке исполнения
# - Исследовательский анализ данных выполнен
# - Проверены экспертные оценки и краудсорсинговые оценки
# - Из датасета исключены те объекты, которые выходят за рамки юридических ограничений
# - Изображения векторизованы
# - Текстовые запросы векторизованы
# - Данные корректно разбиты на тренировочную и тестовую выборки
# - Предложена метрика качества работы модели
# - Предложена модель схожести изображений и текстового запроса
# - Модель обучена
# - По итогам обучения модели сделаны выводы
# - Проведено тестирование работы модели
# - По итогам тестирования визуально сравнили качество поиска

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Заключительный комментарий</b>
#
# Подведем итоги. Я вижу, что в целом с проектом ты справляешься.
#
# Проведено исследование и предобработка данных. Выполнена векторизация изображений и текстовых описаний. Обучены модели для предсказания степени соответствия, а также написана функция для инференса и с её помощью проведено тестирование.
#
#
# Что нужно доделать обязательно:
#
#  - прошу навести порядок с установкой библиотек и импортами
#  - нужно удалить изображения с детьми, а не комментарии, описывающие детей
#  - нужно устранить ошибку с перемешиванием изображений при векторизации
#  - пожалуйста обоснуй выбор метрики
#
# Желтые комментарии на твое усмотрение. Но учитывая что наш подход "не взлетел" и нужно хоть что-то показать заказчику, попробуй показать возможный инференс с помщью CLIP. С библиотекой sentence-transformers это делается буквально в 10 строк.
# Жду твою работу на повторное ревью.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментария студента</b></font>
#
# Что исправила:
#  -  навела порядок в установке библиотек,
#  -  удалены изображения с детьми,
#  -  устранила ошибку с перемешиванием данных,
#  -  обосновала выбор метрики.
#
#
#
# </div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Заключительный комментарий v2</b>
#
# К сожалению очистка датасета от записей, содержащие детские фото проведена неверно. Прошу разобраться и исправить ошибку.</div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>Комментария студента V2</b></font>
#
# Что исправила:
#
#  -  удалены изображения с детьми
#
#
#
# </div>
